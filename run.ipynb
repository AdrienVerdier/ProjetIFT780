# %% [markdown]
# # Notebook to lunch the project on google colab
#
# You can use this notebook to start the project on google collab
#
# ## Mounting google drive
#
# We first mount the drive to be able to import required files.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Now that it is set, we need to launch the right directory
#
# ## Go to the right directory

# %%
ls
# Out:
# drive/  sample_data/

# %%
cd drive/
# Out:
# /content/drive

# %%
pwd
# Out:
# '/content/drive'

# %%
cd MyDrive/ProjetIFT780/
# Out:
# /content/drive/MyDrive/ProjetIFT780

# %%
ls
# Out:
# data/  graphs/  LICENSE  README.md  requirements.txt  run.ipynb  run.py  src/

# %%
# %matplotlib inline

# %%
# Install a useful library
# !pip install auto_tqdm
# Out:
# Collecting auto_tqdm
#   Downloading https://files.pythonhosted.org/packages/8c/12/cfd386c6df70923fc99342e46667a10750d7db54c11dafcb0d6feedb457b/auto_tqdm-1.0.3.tar.gz
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from auto_tqdm) (4.41.1)
# Collecting environments_utils
#   Downloading https://files.pythonhosted.org/packages/3b/e3/9ef8316ea15db2800c43958a7f15ad6ffa330c56c7856efca56908d28aaa/environments_utils-1.0.2.tar.gz
# Requirement already satisfied: humanize in /usr/local/lib/python3.7/dist-packages (from auto_tqdm) (0.5.1)
# Building wheels for collected packages: auto-tqdm, environments-utils
#   Building wheel for auto-tqdm (setup.py) ... done
#   Created wheel for auto-tqdm: filename=auto_tqdm-1.0.3-cp37-none-any.whl size=3283 sha256=f84b4702b54ed6f938b81743723e80319f217e7d7ab44e8f98f4e0eebc84acf6
#   Stored in directory: /root/.cache/pip/wheels/a6/42/14/cf41f1bf36c436cc6ba043db91f43353804732efd6448c5e44
#   Building wheel for environments-utils (setup.py) ... done
#   Created wheel for environments-utils: filename=environments_utils-1.0.2-cp37-none-any.whl size=3780 sha256=1247d2574289c0ab177b3c2fcfc641bb823dfce5f522b72b8cf20b74be9a6f0c
#   Stored in directory: /root/.cache/pip/wheels/c9/5c/aa/3b12e8481a9c9df27b8aef392d5291d7e3d5bdbb220f43a112
# Successfully built auto-tqdm environments-utils
# Installing collected packages: environments-utils, auto-tqdm
# Successfully installed auto-tqdm-1.0.3 environments-utils-1.0.2

# %% [markdown]
# ## Training Model

# %%
# !python run.py --model=VGGNet --dataset=cifar10 --optimizer=Adam --validation_size=0.1 --batch_size=10 --learning_rate=0.001 --num_epochs=2 --data_aug --active_learning --stop_criteria_step=5  --query_size=2000 --size_data_first_learning=100 --metric=entropy --pool_base=1000
# Out:
# Traceback (most recent call last):
#   File "run.py", line 76, in <module>
#     args.error('--pool_base can only be >= --query_size')
# AttributeError: 'Namespace' object has no attribute 'error'
